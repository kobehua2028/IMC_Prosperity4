# %%
import pandas as pd

file_path = "../prices_round_0_day_-1.csv"  # replace with your actual data file name/path
df = pd.read_csv(file_path)
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2
#       3 file_path = "../prices_round_0_day_-1.csv"  # replace with your actual data file name/path
#       4 df = pd.read_csv(file_path)
#
# ModuleNotFoundError: No module named 'pandas'
